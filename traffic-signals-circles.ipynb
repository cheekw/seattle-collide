# %% [markdown]
# Imports for data processing and plotting.

# %%
from geopy import distance
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# Load the data from csv.

# %%
filepath = 'data/'
collisions = pd.read_csv(filepath + 'Collisions.csv')
signals = pd.read_csv(filepath + "Traffic_Signals.csv")
circles = pd.read_csv(filepath + "Traffic_Circles.csv")

# %%
print(collisions.shape)
print(signals.shape)
print(circles.shape)
# Out:
# (203190, 40)
# (1107, 62)
# (1045, 32)

# %% [markdown]
# Filter for NA values and prepare values for plotting.

# %%
# Drop NA values

collisions = collisions.dropna(subset=['X', 'Y'])
collisions.shape

circles = circles.dropna(subset=['X', 'Y'])
circles.CONDITION = circles.CONDITION.astype("category")
dict( enumerate(circles.CONDITION.cat.categories) )
# Out:
# {0: ' ', 1: 'FAIR', 2: 'GOOD', 3: 'POOR'}

# %%
import plotly.graph_objs as go

mapbox_access_token = "pk.eyJ1IjoiYXVzdGluaHNpZWgiLCJhIjoiY2pwN24ybWdwMXFxNjNzcXI1aTF1a2RhbSJ9.I1pGB8PyJfjjFyM0I4HEnw"

colors = ["Black", "Gold", "Green", "Red"]

data = [
    go.Scattermapbox(
        lat=circles['Y'],
        lon=circles['X'],
        mode='markers',
        text=circles['UNITDESC'].str.strip(),
        hoverinfo='text',
        marker=dict(
            size=6, 
            color = circles['CONDITION'].cat.codes.apply(lambda x: colors[x])
        ),
    )
]

layout = go.Layout(
    title = 'Traffic Circles by Location and Condition',
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=47.607569,
            lon=-122.342064
        ),
        pitch=0,
        zoom=10
    ),
)

fig = dict(data=data, layout=layout)

iplot(fig, filename='Seattle Traffic Circles')
# Out:
# <div id="2b7f2b77-2efe-48e7-99ad-e00f6ad0db4a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2b7f2b77-2efe-48e7-99ad-e00f6ad0db4a", [{"hoverinfo": "text", "lat": [47.67940966261109, 47.70322664887175, 47.67333408508362, 47.689835398436095, 47.624386579334974, 47.721119854267855, 47.70433507964362, 47.65669190673825, 47.69602018391888, 47.56290923699642, 47.67956303184228, 47.68143004215846, 47.528308781061256, 47.59443215095732, 47.545319734256346, 47.67235201918211, 47.725100263494504, 47.700398275607434, 47.67771611968667, 47.72124265706586, 47.52649438247138, 47.621113305167675, 47.66946247923085, 47.65054468433321, 47.683217370508615, 47.689109859963274, 47.733212836488256, 47.72685592584889, 47.69949029671842, 47.52647062521841, 47.677596230711785, 47.64143015429034, 47.70688764777122, 47.6589635348535, 47.659838586460026, 47.69707271147835, 47.70473572889344, 47.674849725752146, 47.65578277384586, 47.67417022384564, 47.6187590087277, 47.69381249043289, 47.71209086131426, 47.634742139367845, 47.634742139367845, 47.566489128051735, 47.7028943919867, 47.687492792494744, 47.58690464464786, 47.69092311109296, 47.642014406454074, 47.53569803136114, 47.598327558409814, 47.624267335532686, 47.62684467294901, 47.61634173062161, 47.52613696017042, 47.69572075238365, 47.684734987580754, 47.683293611094435, 47.51899939890386, 47.66286630834297, 47.70434313204194, 47.72841539134578, 47.69420913980465, 47.657945234768675, 47.664897356591084, 47.72204342382593, 47.62208141609222, 47.696053900920354, 47.53209730372076, 47.69601620933221, 47.633354044509844, 47.72145662646429, 47.59556627932621, 47.55
# %% [markdown]
# An overview plot of traffic circles in Seattle by time built.

# %%
# Generate new sample, or use saved one.
col = pd.read_csv("collisions_circles_sampled.csv")
# col = collisions.sample(n=2000)

# %% [markdown]
# Find the closest traffic circle to each collision (running this will take a while, probably a couple minutes.)

# %%
# SKIP THIS IF DATA READ FROM CSV ABOVE #

import scipy

# Generate distances from collision to traffic circle
# mat = scipy.spatial.distance.cdist(col[['Y', 'X']], 
#                               circles[['Y', 'X']], lambda u, v: distance.distance(u, v).kilometers)
# mat
# Out:
# array([[ 2.48561776,  5.15058806,  1.59260153, ...,  5.71881004,
#          6.02828209,  2.18339404],
#        [10.49452692, 13.39685467,  9.85640328, ..., 13.94302257,
#         13.60221098,  8.99173978],
#        [ 5.65965857,  2.01732806,  5.76747129, ...,  3.11099902,
#          2.98942282,  6.56721775],
#        ...,
#        [ 7.00706286,  9.45569033,  6.16815691, ..., 10.28834792,
#          9.48081285,  4.88853292],
#        [ 8.19840378, 10.18544956,  7.25243208, ..., 11.29023624,
#          9.7731918 ,  5.42038129],
#        [ 6.07623014,  4.68442272,  6.88255711, ...,  2.85360177,
#          7.09464954,  8.99877925]])

# %%
# SKIP THIS IF DATA READ FROM CSV ABOVE #

# Find the distance to the closest traffic circle for each collision
# mins = mat.min(axis=1)
# minsIndex = np.argmin(mat, axis=1)

# Convert to meters
# col["CLOSEST_CIRCLE_DIST"] = mins * 1000
# col["CLOSEST_CIRCLE_INDEX"] = minsIndex
# col.to_csv("collisions_circles_sampled.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4dbb53540b01> in <module>()
#       2
#       3 # Find the distance to the closest traffic circle for each collision
# ----> 4 mins = mat.min(axis=1)
#       5 minsIndex = np.argmin(mat, axis=1)
#       6
#
# NameError: name 'mat' is not defined

# %% [markdown]
# We can filter for accidents that happen within, or very close to a traffic circle by filtering the collisions based on distance. Here I'm restricting the data to collisions within 100m of a traffic circle.

# %%
# Filter for accidents inside a traffic circle
close = col[col["CLOSEST_CIRCLE_DIST"] <= 100]
close.shape
# Out:
# (165, 43)

# %%
from toolz import interleave

closestCircles = circles.loc[close['CLOSEST_CIRCLE_INDEX'], :]

# Don't include the first column, which just has indices
df = close.drop(close.columns[0], axis=1)

empty = pd.DataFrame(np.nan, index=range(len(df)), columns=df.columns)

inter = pd.DataFrame(interleave([df.values, closestCircles.values, empty.values]))
# Out:
#              0          1         2         3         4   \
# 0   -122.312771  47.614499   92323.0  106370.0    106370
# 1   -122.312773  47.614113      35.0  509014.0   TRC-188
# 2           NaN        NaN       NaN       NaN       NaN
# 3   -122.351958  47.692408   30378.0   44611.0     44611
# 4   -122.352621  47.692410     401.0  509653.0   TRC-881
# 5           NaN        NaN       NaN       NaN       NaN
# 6   -122.314299  47.618788  152649.0  181453.0    181493
# 7   -122.315604  47.618778     345.0  509106.0   TRC-156
# 8           NaN        NaN       NaN       NaN       NaN
# 9   -122.347419  47.661093  173730.0  222656.0    222936
# 10  -122.348633  47.660761     421.0  509070.0   TRC-999
# 11          NaN        NaN       NaN       NaN       NaN
# 12  -122.311450  47.617028  157678.0  193433.0    193513
# 13  -122.311456  47.616446     648.0  509169.0   TRC-194
# 14          NaN        NaN       NaN       NaN       NaN
# 15  -122.365636  47.668653   55276.0   69582.0     69582
# 16  -122.365096  47.669430     148.0  526961.0  TRC-1097
# 17          NaN        NaN       NaN       NaN       NaN
# 18  -122.310260  47.594215   44663.0   59207.0     59207
# 19  -122.309121  47.594432    1020.0  509878.0   TRC-971
# 20          NaN        NaN       NaN       NaN       NaN
# 21  -122.323946  47.645622  106457.0  121941.0    121941
# 22  -122.324524  47.645622     712.0  509298.0   TRC-932
# 23          NaN        NaN       NaN       NaN       NaN
# 24  -122.318393  47.663565   37477.0   51912.0     51912
# 25  -122.318398  47.663125     746.0  509719.0   TRC-799
# 26          NaN        NaN       NaN       NaN       NaN
# 27  -122.324310  47.688251   46565.0   60480.0     60480
# 28  -122.324323  47.687527     938.0  509049.0   TRC-721
# 29          NaN        NaN       NaN       NaN       NaN
# ..          ...        ...       ...       ...       ...
# 465 -122.383432  47.673828  127266.0  141919.0    141919
# 466 -122.384741  47.673829     312.0  509120.0   TRC-370
# 467         NaN        NaN       NaN       NaN       NaN
# 468 -122.325866  47.616340  151370.0  178839.0    178879
# 469 -122.325543  47.616342      11.0  509767.0  TRC-1060
# 470         NaN        NaN       NaN       NaN       NaN
# 471 -122.305562  47.582956   89062.0  104416.0    104416
# 472 -122.305557  47.583667     434.0  509301.0   TRC-355
# 473         NaN        NaN       NaN       NaN       NaN
# 474 -122.272656  47.532093   83820.0   98401.0     98401
# 475 -122.272715  47.531565     709.0  509490.0   TRC-711
# 476         NaN        NaN       NaN       NaN       NaN
# 477 -122.285042  47.557849  189038.0  248543.0    249123
# 478 -122.286141  47.557851     371.0  509720.0   TRC-581
# 479         NaN        NaN       NaN       NaN       NaN
# 480 -122.312117  47.614771   72121.0   87551.0     87551
# 481 -122.312773  47.614113      35.0  509014.0   TRC-188
# 482         NaN        NaN       NaN       NaN       NaN
# 483 -122.313961  47.614118  104033.0  120431.0    120431
# 484 -122.312773  47.614113      35.0  509014.0   TRC-188
# 485         NaN        NaN       NaN       NaN       NaN
# 486 -122.347297  47.697342   39714.0   54048.0     54048
# 487 -122.347303  47.697816     167.0  509601.0   TRC-997
# 488         NaN        NaN       NaN       NaN       NaN
# 489 -122.333156  47.660294   53327.0   67283.0     67283
# 490 -122.333743  47.660296     386.0  509021.0  TRC-1013
# 491         NaN        NaN       NaN       NaN       NaN
# 492 -122.296766  47.602155  192961.0  261515.0    262255
# 493 -122.297858  47.602659     379.0  508946.0   TRC-447
# 494         NaN        NaN       NaN       NaN       NaN
#
#                                                     5          6   \
# 0                                              3283545    Matched
# 1    15TH AVE AND E PIKE ST                        ...       GOOD
# 2                                                  NaN        NaN
# 3                                              2022919    Matched
# 4    DAYTON AVE N AND N 87TH ST                    ...       GOOD
# 5                                                  NaN        NaN
# 6                                              3642418    Matched
# 7    13TH AVE AND E DENNY WAY                      ...       GOOD
# 8                                                  NaN        NaN
# 9                                              3501779    Matched
# 10   LINDEN AVE N AND N ALLEN PL                   ...       GOOD
# 11                                                 NaN        NaN
# 12                                             3707251    Matched
# 13   16TH AVE AND E OLIVE ST                       ...       GOOD
# 14                                                 NaN        NaN
# 15                                             C693657    Matched
# 16   7TH AVE NW AND NW 56TH ST                     ...       GOOD
# 17                                                 NaN        NaN
# 18                                             1784493    Matched
# 19   HIAWATHA PL S AND S CHARLES ST                ...       GOOD
# 20                                                 NaN        NaN
# 21                                             3567732    Matched
# 22   FRANKLIN AVE E AND E HAMLIN ST                ...       GOOD
# 23                                                 NaN        NaN
# 24                                             C671768    Matched
# 25   9TH AVE NE AND NE 47TH ST                     ...       GOOD
# 26                                                 NaN        NaN
# 27                                             2604210    Matched
# 28   4TH AVE NE AND NE 81ST ST                     ...       GOOD
# 29                                                 NaN        NaN
# ..                                                 ...        ...
# 465                                            3551034    Matched
# 466  22ND AVE NW AND NW 62ND ST                    ...       GOOD
# 467                                                NaN        NaN
# 468                                            3588565    Matched
# 469  SUMMIT AVE AND E OLIVE ST                     ...       GOOD
# 470                                                NaN        NaN
# 471                                            3282182    Matched
# 472  21ST AVE S AND S WALKER ST                    ...       GOOD
# 473                                                NaN        NaN
# 474                                            C721755    Matched
# 475  48TH AVE S AND S KENYON ST                    ...       GOOD
# 476                                                NaN        NaN
# 477                                            E711121    Matched
# 478  37TH AVE S AND S FERDINAND ST                 ...       GOOD
# 479                                                NaN        NaN
# 480                                            8002040  Unmatched
# 481  15TH AVE AND E PIKE ST                        ...       GOOD
# 482                                                NaN        NaN
# 483                                            3386833    Matched
# 484  15TH AVE AND E PIKE ST                        ...       GOOD
# 485                                                NaN        NaN
# 486                                            2178626    Matched
# 487  LINDEN AVE N AND N 95TH ST                    ...       GOOD
# 488                                                NaN        NaN
# 489                                            C694727    Matched
# 490  MERIDIAN AVE N AND N 44TH ST                  ...       GOOD
# 491                                                NaN        NaN
# 492                                            C814690  Unmatched
# 493  27TH AVE AND E FIR ST                         ...       GOOD
# 494                                                NaN        NaN
#
#                            7      8   \
# 0                Intersection  30136
# 1    2009-07-06T00:00:00.000Z  INSVC
# 2                         NaN    NaN
# 3                       Block    NaN
# 4    2009-09-24T00:00:00.000Z  INSVC
# 5                         NaN    NaN
# 6                Intersection  29062
# 7    2009-07-06T00:00:00.000Z  INSVC
# 8                         NaN    NaN
# 9                       Block    NaN
# 10   2009-09-15T00:00:00.000Z  INSVC
# 11                        NaN    NaN
# 12                      Block    NaN
# 13   2009-07-16T00:00:00.000Z  INSVC
# 14                        NaN    NaN
# 15                      Block    NaN
# 16   2010-11-19T00:00:00.000Z  INSVC
# 17                        NaN    NaN
# 18                      Block    NaN
# 19   2009-09-24T00:00:00.000Z  INSVC
# 20                        NaN    NaN
# 21                      Block    NaN
# 22   2009-07-27T00:00:00.000Z  INSVC
# 23                        NaN    NaN
# 24                      Block    NaN
# 25   2009-09-15T00:00:00.000Z  INSVC
# 26                        NaN    NaN
# 27               Intersection  24526
# 28   2009-08-03T00:00:00.000Z  INSVC
# 29                        NaN    NaN
# ..                        ...    ...
# 465                     Block    NaN
# 466  2009-09-21T00:00:00.000Z  INSVC
# 467                       NaN    NaN
# 468                     Block    NaN
# 469  2009-09-24T00:00:00.000Z  INSVC
# 470                       NaN    NaN
# 471              Intersection  31577
# 472  2009-09-15T00:00:00.000Z  INSVC
# 473                       NaN    NaN
# 474                     Block    NaN
# 475  2009-09-15T00:00:00.000Z  INSVC
# 476                       NaN    NaN
# 477              Intersection  33571
# 478  2009-09-24T00:00:00.000Z  INSVC
# 479                       NaN    NaN
# 480                     Block    NaN
# 481  2009-07-06T00:00:00.000Z  INSVC
# 482                       NaN    NaN
# 483                     Block    NaN
# 484  2009-07-06T00:00:00.000Z  INSVC
# 485                       NaN    NaN
# 486                     Block    NaN
# 487  2009-07-27T00:00:00.000Z  INSVC
# 488                       NaN    NaN
# 489                     Block    NaN
# 490  2009-07-27T00:00:00.000Z  INSVC
# 491                       NaN    NaN
# 492                     Block    NaN
# 493  2009-09-09T00:00:00.000Z  INSVC
# 494                       NaN    NaN
#
#                                                     9   ...      32  \
# 0                            15TH AVE AND E MADISON ST  ...     NaN
# 1                                                 SDOT  ...    None
# 2                                                  NaN  ...     NaN
# 3    N 87TH ST BETWEEN DAYTON AVE N AND EVANSTON AVE N  ...     NaN
# 4                                                 SDOT  ...    None
# 5                                                  NaN  ...     NaN
# 6                             14TH AVE AND E DENNY WAY  ...     NaN
# 7                                                 SDOT  ...    None
# 8                                                  NaN  ...     NaN
# 9     N PHINNEY WAY BETWEEN N 45TH ST AND AURORA AVE N  ...     NaN
# 10                                                SDOT  ...    None
# 11                                                 NaN  ...     NaN
# 12         16TH AVE BETWEEN E OLIVE ST AND E HOWELL ST  ...     NaN
# 13                                                SDOT  ...    None
# 14                                                 NaN  ...     NaN
# 15      NW MARKET ST BETWEEN 7TH AVE NW AND 8TH AVE NW  ...     NaN
# 16                                                SDOT  ...    None
# 17                                                 NaN  ...     NaN
# 18   RAINIER AVE S BETWEEN S CHARLES N ST AND S CHA...  ...     NaN
# 19                                                SDOT  ...    None
# 20                                                 NaN  ...     NaN
# 21   E HAMLIN ST BETWEEN FRANKLIN AVE E AND BOYLSTO...  ...     NaN
# 22                                                SDOT  ...    None
# 23                                                 NaN  ...     NaN
# 24        9TH AVE NE BETWEEN NE 47TH ST AND NE 48TH ST  ...     NaN
# 25                                                SDOT  ...    None
# 26                                                 NaN  ...     NaN
# 27                           4TH AVE NE AND NE 82ND ST  ...     NaN
# 28                                                SDOT  ...    None
# 29                                                 NaN  ...     NaN
# ..                                                 ...  ...     ...
# 465     NW 62ND ST BETWEEN 20TH AVE NW AND 22ND AVE NW  ...     NaN
# 466                                               SDOT  ...    None
# 467                                                NaN  ...     NaN
# 468      E OLIVE ST BETWEEN CRAWFORD PL AND SUMMIT AVE  ...     NaN
# 469                                               SDOT  ...    None
# 470                                                NaN  ...     NaN
# 471                        21ST AVE S AND S COLLEGE ST  ...       Y
# 472                                               SDOT  ...    None
# 473                                                NaN  ...     NaN
# 474    48TH AVE S BETWEEN S CHICAGO ST AND S KENYON ST  ...     NaN
# 475                                               SDOT  ...    None
# 476                                                NaN  ...     NaN
# 477                   RAINIER AVE S AND S FERDINAND ST  ...     NaN
# 478                                               SDOT  ...    None
# 479                                                NaN  ...     NaN
# 480         E MADISON ST BETWEEN 15TH AVE AND 16TH AVE  ...     NaN
# 481                                               SDOT  ...    None
# 482                                                NaN  ...     NaN
# 483        E PIKE ST BETWEEN 14TH AVE AND E MADISON ST  ...     NaN
# 484                                               SDOT  ...    None
# 485                                                NaN  ...     NaN
# 486       LINDEN AVE N BETWEEN N 94TH ST AND N 95TH ST  ...     NaN
# 487                                               SDOT  ...    None
# 488                                                NaN  ...     NaN
# 489  N 44TH ST BETWEEN MERIDIAN AVE N AND BAGLEY AVE N  ...     NaN
# 490                                               SDOT  ...    None
# 491                                                NaN  ...     NaN
# 492  M L KING JR WAY BETWEEN E YESLER WAY AND E FIR ST  ...     NaN
# 493                                               SDOT  ...    None
# 494                                                NaN  ...     NaN
#
#              33    34    35  \
# 0     9181029.0   NaN    28
# 1           NaN  None  None
# 2           NaN   NaN   NaN
# 3     5112006.0   NaN    32
# 4           NaN  None  None
# 5           NaN   NaN   NaN
# 6           NaN   NaN    10
# 7           NaN  None  None
# 8           NaN   NaN   NaN
# 9           NaN   NaN    14
# 10          NaN  None  None
# 11          NaN   NaN   NaN
# 12          NaN   NaN    45
# 13          NaN  None  None
# 14          NaN   NaN   NaN
# 15    7288057.0   NaN    14
# 16          NaN  None  None
# 17          NaN   NaN   NaN
# 18    6131004.0   NaN    14
# 19          NaN  None  None
# 20          NaN   NaN   NaN
# 21   11354027.0     Y    30
# 22          NaN  None  None
# 23          NaN   NaN   NaN
# 24    6206037.0   NaN    32
# 25          NaN  None  None
# 26          NaN   NaN   NaN
# 27    6343027.0   NaN    10
# 28          NaN  None  None
# 29          NaN   NaN   NaN
# ..          ...   ...   ...
# 465  12153025.0   NaN    32
# 466         NaN  None  None
# 467         NaN   NaN   NaN
# 468         NaN   NaN    32
# 469         NaN  None  None
# 470         NaN   NaN   NaN
# 471   9006018.0     Y    45
# 472         NaN  None  None
# 473         NaN   NaN   NaN
# 474   9157035.0   NaN    10
# 475         NaN  None  None
# 476         NaN   NaN   NaN
# 477         NaN   NaN    13
# 478         NaN  None  None
# 479         NaN   NaN   NaN
# 480   8002040.0   NaN   NaN
# 481         NaN  None  None
# 482         NaN   NaN   NaN
# 483  11026022.0   NaN    32
# 484         NaN  None  None
# 485         NaN   NaN   NaN
# 486   6049036.0   NaN    32
# 487         NaN  None  None
# 488         NaN   NaN   NaN
# 489   7292078.0   NaN    32
# 490         NaN  None  None
# 491         NaN   NaN   NaN
# 492         NaN   NaN
# 493         NaN  None  None
# 494         NaN   NaN   NaN
#
#                                                     36       37   38    39  \
# 0    From opposite direction - one left turn - one ...      0.0  0.0     N
# 1                                                 None      NaN  NaN  None
# 2                                                  NaN      NaN  NaN   NaN
# 3                               One parked--one moving      0.0  0.0     N
# 4                                                 None      NaN  NaN  None
# 5                                                  NaN      NaN  NaN   NaN
# 6                                    Entering at angle      0.0  0.0     N
# 7                                                 None      NaN  NaN  None
# 8                                                  NaN      NaN  NaN   NaN
# 9    From same direction - both going straight - on...      0.0  0.0     N
# 10                                                None      NaN  NaN  None
# 11                                                 NaN      NaN  NaN   NaN
# 12                              Vehicle - Pedalcyclist      0.0  0.0     N
# 13                                                None      NaN  NaN  None
# 14                                                 NaN      NaN  NaN   NaN
# 15   From same direction - both going straight - on...      0.0  0.0     N
# 16                                                None      NaN  NaN  None
# 17                                                 NaN      NaN  NaN   NaN
# 18   From same direction - both going straight - on...      0.0  0.0     N
# 19                                                None      NaN  NaN  None
# 20                                                 NaN      NaN  NaN   NaN
# 21                From opposite direction - all others      0.0  0.0     N
# 22                                                None      NaN  NaN  None
# 23                                                 NaN      NaN  NaN   NaN
# 24                              One parked--one moving      0.0  0.0     N
# 25                                                None      NaN  NaN  None
# 26                                                 NaN      NaN  NaN   NaN
# 27                                   Entering at angle      0.0  0.0     N
# 28                                                None      NaN  NaN  None
# 29                                                 NaN      NaN  NaN   NaN
# ..                                                 ...      ...  ...   ...
# 465                             One parked--one moving      0.0  0.0     N
# 466                                               None      NaN  NaN  None
# 467                                                NaN      NaN  NaN   NaN
# 468                             One parked--one moving      0.0  0.0     N
# 469                                               None      NaN  NaN  None
# 470                                                NaN      NaN  NaN   NaN
# 471                             Vehicle - Pedalcyclist  38190.0  0.0     N
# 472                                               None      NaN  NaN  None
# 473                                                NaN      NaN  NaN   NaN
# 474                                  Entering at angle      0.0  0.0     N
# 475                                               None      NaN  NaN  None
# 476                                                NaN      NaN  NaN   NaN
# 477  From same direction - both going straight - bo...      0.0  0.0     N
# 478                                               None      NaN  NaN  None
# 479                                                NaN      NaN  NaN   NaN
# 480                                                NaN      0.0  0.0     N
# 481                                               None      NaN  NaN  None
# 482                                                NaN      NaN  NaN   NaN
# 483                             One parked--one moving      0.0  0.0     N
# 484                                               None      NaN  NaN  None
# 485                                                NaN      NaN  NaN   NaN
# 486                             One parked--one moving      0.0  0.0     N
# 487                                               None      NaN  NaN  None
# 488                                                NaN      NaN  NaN   NaN
# 489                             One parked--one moving      0.0  0.0     N
# 490                                               None      NaN  NaN  None
# 491                                                NaN      NaN  NaN   NaN
# 492                                                NaN      0.0  0.0     N
# 493                                               None      NaN  NaN  None
# 494                                                NaN      NaN  NaN   NaN
#
#             40     41
# 0    42.956474   79.0
# 1          NaN    NaN
# 2          NaN    NaN
# 3    49.764350  443.0
# 4          NaN    NaN
# 5          NaN    NaN
# 6    98.171941  387.0
# 7          NaN    NaN
# 8          NaN    NaN
# 9    98.372689  463.0
# 10         NaN    NaN
# 11         NaN    NaN
# 12   64.776223  689.0
# 13         NaN    NaN
# 14         NaN    NaN
# 15   95.454005  192.0
# 16         NaN    NaN
# 17         NaN    NaN
# 18   88.994377   13.0
# 19         NaN    NaN
# 20         NaN    NaN
# 21   43.438184  751.0
# 22         NaN    NaN
# 23         NaN    NaN
# 24   48.922162  785.0
# 25         NaN    NaN
# 26         NaN    NaN
# 27   80.476866  976.0
# 28         NaN    NaN
# 29         NaN    NaN
# ..         ...    ...
# 465  98.293778  355.0
# 466        NaN    NaN
# 467        NaN    NaN
# 468  24.290159   55.0
# 469        NaN    NaN
# 470        NaN    NaN
# 471  79.078428  476.0
# 472        NaN    NaN
# 473        NaN    NaN
# 474  58.917334  748.0
# 475        NaN    NaN
# 476        NaN    NaN
# 477  82.711485  413.0
# 478        NaN    NaN
# 479        NaN    NaN
# 480  88.281259   79.0
# 481        NaN    NaN
# 482        NaN    NaN
# 483  89.243997   79.0
# 484        NaN    NaN
# 485        NaN    NaN
# 486  52.734686  211.0
# 487        NaN    NaN
# 488        NaN    NaN
# 489  44.142097  428.0
# 490        NaN    NaN
# 491        NaN    NaN
# 492  99.432154  421.0
# 493        NaN    NaN
# 494        NaN    NaN
#
# [495 rows x 42 columns]

# %%
data = [
    go.Scattermapbox(
        lat=inter[1], # X
        lon=inter[0], # Y
        mode='lines',
        name="Distance from nearest traffic circle",
        opacity = 0.5,
        hoverinfo='text',
        marker=dict(
            size = 4,
            color="Black"
        ),
    ), go.Scattermapbox(
        lat=closestCircles["Y"],
        lon=closestCircles["X"],
        mode='markers',
        name="Traffic Circle",
        opacity = 0.5,
        text=closestCircles['UNITDESC'].str.strip(),
        hoverinfo='text',
        marker=dict(
            size = 8,
            color="Blue"
        ),
    ), go.Scattermapbox(
        lat=close["Y"],
        lon=close["X"],
        mode='markers',
        name="Collision", 
        opacity = 0.5,
        text=close['LOCATION'].str.strip(),
        hoverinfo='text',
        marker=dict(
            size = 7,
            color="Red"
        ),
    )
]

layout = go.Layout(
    title = 'Traffic Collisions',
    width = 1000,
    height = 1000,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=47.607569,
            lon=-122.342064
        ),
        pitch=0,
        zoom=10.5
    ),
    showlegend=True
)

fig = dict(data=data, layout=layout)

iplot(fig, filename='Seattle Traffic Circles')
# Out:
# <div id="a432f7ed-e728-491b-abe4-d841e145c5d8" style="height: 1000px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a432f7ed-e728-491b-abe4-d841e145c5d8", [{"hoverinfo": "text", "lat": [47.61449898544244, 47.61411262896574, null, 47.69240834698381, 47.69241034101899, null, 47.618787513673524, 47.61877809397897, null, 47.66109339418945, 47.66076104332444, null, 47.61702818888645, 47.61644559125036, null, 47.668652786950645, 47.669429961455954, null, 47.59421530249815, 47.59443215095732, null, 47.64562176944148, 47.64562238942878, null, 47.66356453988443, 47.66312454144042, null, 47.688250741966115, 47.68752697781108, null, 47.69058707308702, 47.689835933385964, null, 47.70077328769561, 47.70032070328927, null, 47.60926927483969, 47.609272709247534, null, 47.55116466984687, 47.55041642965646, null, 47.66979398291398, 47.669429961455954, null, 47.655382876420056, 47.65538384641941, null, 47.660296472018345, 47.660296472018345, null, 47.61222470291133, 47.61154371480974, null, 47.6869390830484, 47.68621698084497, null, 47.58455513374898, 47.584552839014975, null, 47.60474570464207, 47.60433046405902, null, 47.62522053799094, 47.625214931988886, null, 47.60956418904549, 47.610351554750565, null, 47.57882372595874, 47.57832656143254, null, 47.679528668312436, 47.679525107981824, null, 47.60980237021236, 47.61051614134981, null, 47.566486974918526, 47.56648767598138, null, 47.644493218271954, 47.64449212106364, null, 47.70361077157626, 47.70433507964362, null, 47.70143785929966, 47.70143785929966, null